# %% [markdown]
# # Intro to Python
# This notebook has some basic Python commands.

# %%
name = "Gisele"
age = 47
awesome = True

# %%
print(name)
# Out:
# Gisele

# %%
def bouncer(age):
    if(age >= 21):
        return "You can drink"
    if(age >= 18):
        return "You can dance"
    return "Get out!"

# %%
bouncer(16)
# Out:
# 'Get out!'

# %%
bouncer(19)
# Out:
# 'You can dance'

# %%
bouncer(47)
# Out:
# 'You can drink'

# %%
for i in range(0,10):
    print("Python is cool! 😎")
# Out:
# Python is cool! 😎
# Python is cool! 😎
# Python is cool! 😎
# Python is cool! 😎
# Python is cool! 😎
# Python is cool! 😎
# Python is cool! 😎
# Python is cool! 😎
# Python is cool! 😎
# Python is cool! 😎

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
data = pd.DataFrame(np.random.randn(100,4), columns=['A', 'B', 'C', 'D'])

# %%
data.head()
# Out:
#           A         B         C         D
# 0 -0.333340  0.924664  1.138710 -0.986179
# 1 -0.252135 -0.565242 -1.046021  1.412003
# 2 -0.698334 -0.808847 -0.816129  3.035236
# 3  0.379796  1.589208  0.279944 -1.342802
# 4 -0.168107  0.509114  0.560029  0.015624

# %%
plt.scatter(data['A'], data['D'])

# %%
sns.pairplot(data)
